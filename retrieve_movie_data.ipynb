# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url=(f'{url}fq={filter_query}&begin_date={begin_date}&end_date={end_date}&fl={field_list}&sort={sort}&api-key={nyt_api_key}&page=')

# %%
# Create an empty list to store the reviews
reviews_list=[]

# loop through pages 0-19
for page in range (0,20):
    
    # create query with a page number
    # API results show 10 articles at a time
    page_url = f"{query_url}&page={page}"
    
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(page_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        
        # loop through the reviews["response"]["docs"] and append each review to the list
        for article in reviews['response']['docs']:
            reviews_list.append(article) 
            
        # Print the page that was just retrieved
        print("Records Retrieved from Page:",page)
    except:
        
        # Print the page number that had no results then break from the loop
        print('Results Not Found on Page',page)
        break
# Out:
# Records Retrieved from Page: 0
# Records Retrieved from Page: 1
# Records Retrieved from Page: 2
# Records Retrieved from Page: 3
# Records Retrieved from Page: 4
# Records Retrieved from Page: 5
# Records Retrieved from Page: 6
# Records Retrieved from Page: 7
# Records Retrieved from Page: 8
# Records Retrieved from Page: 9
# Records Retrieved from Page: 10
# Records Retrieved from Page: 11
# Records Retrieved from Page: 12
# Records Retrieved from Page: 13
# Records Retrieved from Page: 14
# Records Retrieved from Page: 15
# Records Retrieved from Page: 16
# Records Retrieved from Page: 17
# Records Retrieved from Page: 18
# Records Retrieved from Page: 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5],indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df=pd.json_normalize(reviews_list)

reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df['title']=reviews_df["headline.main"].apply(lambda sub_string: sub_string[sub_string.find("\u2018")+1:sub_string.find("\u2019 Review")])

reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df['keywords']=reviews_df['keywords'].apply(extract_keywords)

reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles_list=reviews_df['title'].to_list()

titles_list
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list=[]

# Create a request counter to sleep the requests after a multiple of 50 requests
request_counter = 0

# Loop through the titles
for title in titles_list:
    
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter > 0:
        print("Sleeping for 1 seconds to avoid rate limit...")
        time.sleep(1)  
        
    # Add 1 to the request counter
    request_counter += 1

    try:
        # Perform a "GET" request for The Movie Database
        encoded_title = requests.utils.quote(title)
        search_response = requests.get(f"{url}{encoded_title}&api_key={tmdb_api_key}")
        
        # Include a try clause to search for the full movie details.
        # Use the except clause to print out a statement if a movie is not found.
        if search_response.ok and search_response.json()['results']:
            movie = search_response.json()['results'][0]
           
            # Get movie id 
            movie_id = movie['id']

            # Make a request for the full movie details
            details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}&append_to_response=credits"
            
            # Execute "GET" request with url
            details_response = requests.get(details_url)

            if details_response.ok:
                details = details_response.json()
                
                # Extract the genre names into a list
                genres = [genre['name'] for genre in details.get('genres', [])]
                
                # Extract the spoken_languages' English name into a list
                languages = [lang['english_name'] for lang in details.get('spoken_languages', [])]
                
                # Extract the production_countries' name into a list
                countries = [country['name'] for country in details.get('production_countries', [])]

                # Add the relevant data to a dictionary and append it to the tmdb_movies_list list
                movie_dict = {
                    'title': title,
                    'genres': genres,
                    'languages': languages,
                    'countries': countries}
                
                tmdb_movies_list.append(movie_dict)
                
                # Print out the title that was found
                print(f"Found : {title}")
        else:
            print(f"No results found for {title}")

    except Exception as e:
        print(f"An error occurred while processing {title}: {e}")
# Out:
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Sleeping for 1 seconds to avoid rate limit...
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Sleeping for 1 seconds to avoid rate limit...
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Sleeping for 1 seconds to avoid rate limit...
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl
# Found : The Attachment Diaries
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# Found : You Can Live Forever
# Found : A Tourist’s Guide to Love
# Found : Other People’s Children
# Found : One True Loves
# Found : The Lost Weekend: A Love Story
# Found : A Thousand and One
# Found : Your Place or Mine
# Found : Love in the Time of Fentanyl

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5],indent=4))

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                               title                              genres  \
# 0            The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# 1              You Can Live Forever                    [Drama, Romance]
# 2         A Tourist’s Guide to Love                   [Romance, Comedy]
# 3           Other People’s Children                     [Drama, Comedy]
# 4                    One True Loves            [Romance, Comedy, Drama]
# ..                              ...                                 ...
# 175                  One True Loves            [Romance, Comedy, Drama]
# 176  The Lost Weekend: A Love Story                       [Documentary]
# 177              A Thousand and One                      [Drama, Crime]
# 178              Your Place or Mine                   [Romance, Comedy]
# 179    Love in the Time of Fentanyl                       [Documentary]
#
#                           languages  \
# 0                         [Spanish]
# 1                 [English, French]
# 2             [English, Vietnamese]
# 3                 [French, English]
# 4                [English, Spanish]
# ..                              ...
# 175              [English, Spanish]
# 176                       [English]
# 177  [English, Spanish, Portuguese]
# 178                       [English]
# 179                       [English]
#
#                                       countries
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2                    [United States of America]
# 3                                      [France]
# 4    [Czech Republic, United States of America]
# ..                                          ...
# 175  [Czech Republic, United States of America]
# 176                  [United States of America]
# 177                  [United States of America]
# 178                  [United States of America]
# 179          [Canada, United States of America]
#
# [180 rows x 4 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df,tmdb_df, on='title', how='outer')

merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 3615  https://www.nytimes.com/2023/02/02/movies/love...
# 3616  https://www.nytimes.com/2023/02/02/movies/love...
# 3617  https://www.nytimes.com/2023/02/02/movies/love...
# 3618  https://www.nytimes.com/2023/02/02/movies/love...
# 3619  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 3615  To combat the overdose crisis, a group that in...  The New York Times
# 3616  To combat the overdose crisis, a group that in...  The New York Times
# 3617  To combat the overdose crisis, a group that in...  The New York Times
# 3618  To combat the overdose crisis, a group that in...  The New York Times
# 3619  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 3615  subject: Documentary Films and Programs;subjec...
# 3616  subject: Documentary Films and Programs;subjec...
# 3617  subject: Documentary Films and Programs;subjec...
# 3618  subject: Documentary Films and Programs;subjec...
# 3619  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 3615  2023-02-02T12:00:11+0000         306
# 3616  2023-02-02T12:00:11+0000         306
# 3617  2023-02-02T12:00:11+0000         306
# 3618  2023-02-02T12:00:11+0000         306
# 3619  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 3615  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3616  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3617  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3618  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3619  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline headline.name  \
# 0                       None        The Attachment Diaries          None
# 1                       None        The Attachment Diaries          None
# 2                       None        The Attachment Diaries          None
# 3                       None        The Attachment Diaries          None
# 4                       None        The Attachment Diaries          None
# ...                      ...                           ...           ...
# 3615                    None  Love in the Time Of Fentanyl          None
# 3616                    None  Love in the Time Of Fentanyl          None
# 3617                    None  Love in the Time Of Fentanyl          None
# 3618                    None  Love in the Time Of Fentanyl          None
# 3619                    None  Love in the Time Of Fentanyl          None
#
#      headline.seo headline.sub         byline.original  \
# 0            None         None  By Jeannette Catsoulis
# 1            None         None  By Jeannette Catsoulis
# 2            None         None  By Jeannette Catsoulis
# 3            None         None  By Jeannette Catsoulis
# 4            None         None  By Jeannette Catsoulis
# ...           ...          ...                     ...
# 3615         None         None   By Concepción de León
# 3616         None         None   By Concepción de León
# 3617         None         None   By Concepción de León
# 3618         None         None   By Concepción de León
# 3619         None         None   By Concepción de León
#
#                                           byline.person byline.organization  \
# 0     [{'firstname': 'Jeannette', 'middlename': None...                None
# 1     [{'firstname': 'Jeannette', 'middlename': None...                None
# 2     [{'firstname': 'Jeannette', 'middlename': None...                None
# 3     [{'firstname': 'Jeannette', 'middlename': None...                None
# 4     [{'firstname': 'Jeannette', 'middlename': None...                None
# ...                                                 ...                 ...
# 3615  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3616  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3617  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3618  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3619  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                              title                              genres  \
# 0           The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# 1           The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# 2           The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# 3           The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# 4           The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# ...                            ...                                 ...
# 3615  Love in the Time of Fentanyl                       [Documentary]
# 3616  Love in the Time of Fentanyl                       [Documentary]
# 3617  Love in the Time of Fentanyl                       [Documentary]
# 3618  Love in the Time of Fentanyl                       [Documentary]
# 3619  Love in the Time of Fentanyl                       [Documentary]
#
#       languages                           countries
# 0     [Spanish]                         [Argentina]
# 1     [Spanish]                         [Argentina]
# 2     [Spanish]                         [Argentina]
# 3     [Spanish]                         [Argentina]
# 4     [Spanish]                         [Argentina]
# ...         ...                                 ...
# 3615  [English]  [Canada, United States of America]
# 3616  [English]  [Canada, United States of America]
# 3617  [English]  [Canada, United States of America]
# 3618  [English]  [Canada, United States of America]
# 3619  [English]  [Canada, United States of America]
#
# [3620 rows x 20 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'languages', 'countries']

# Create a list of characters to remove
characters_to_remove = ['[', ']', "'"]

# Loop through the list of columns to fix
for col in columns_to_fix:
    
    # Convert the column to type 'str'
    merged_df[col] = merged_df[col].astype(str)

    # Loop through characters to remove
    for char in characters_to_remove:
        merged_df[col] = merged_df[col].str.replace(char, '')

# Display the fixed DataFrame
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 3615  https://www.nytimes.com/2023/02/02/movies/love...
# 3616  https://www.nytimes.com/2023/02/02/movies/love...
# 3617  https://www.nytimes.com/2023/02/02/movies/love...
# 3618  https://www.nytimes.com/2023/02/02/movies/love...
# 3619  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 3615  To combat the overdose crisis, a group that in...  The New York Times
# 3616  To combat the overdose crisis, a group that in...  The New York Times
# 3617  To combat the overdose crisis, a group that in...  The New York Times
# 3618  To combat the overdose crisis, a group that in...  The New York Times
# 3619  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 3615  subject: Documentary Films and Programs;subjec...
# 3616  subject: Documentary Films and Programs;subjec...
# 3617  subject: Documentary Films and Programs;subjec...
# 3618  subject: Documentary Films and Programs;subjec...
# 3619  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 3615  2023-02-02T12:00:11+0000         306
# 3616  2023-02-02T12:00:11+0000         306
# 3617  2023-02-02T12:00:11+0000         306
# 3618  2023-02-02T12:00:11+0000         306
# 3619  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 3615  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3616  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3617  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3618  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3619  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline headline.name  \
# 0                       None        The Attachment Diaries          None
# 1                       None        The Attachment Diaries          None
# 2                       None        The Attachment Diaries          None
# 3                       None        The Attachment Diaries          None
# 4                       None        The Attachment Diaries          None
# ...                      ...                           ...           ...
# 3615                    None  Love in the Time Of Fentanyl          None
# 3616                    None  Love in the Time Of Fentanyl          None
# 3617                    None  Love in the Time Of Fentanyl          None
# 3618                    None  Love in the Time Of Fentanyl          None
# 3619                    None  Love in the Time Of Fentanyl          None
#
#      headline.seo headline.sub         byline.original  \
# 0            None         None  By Jeannette Catsoulis
# 1            None         None  By Jeannette Catsoulis
# 2            None         None  By Jeannette Catsoulis
# 3            None         None  By Jeannette Catsoulis
# 4            None         None  By Jeannette Catsoulis
# ...           ...          ...                     ...
# 3615         None         None   By Concepción de León
# 3616         None         None   By Concepción de León
# 3617         None         None   By Concepción de León
# 3618         None         None   By Concepción de León
# 3619         None         None   By Concepción de León
#
#                                           byline.person byline.organization  \
# 0     [{'firstname': 'Jeannette', 'middlename': None...                None
# 1     [{'firstname': 'Jeannette', 'middlename': None...                None
# 2     [{'firstname': 'Jeannette', 'middlename': None...                None
# 3     [{'firstname': 'Jeannette', 'middlename': None...                None
# 4     [{'firstname': 'Jeannette', 'middlename': None...                None
# ...                                                 ...                 ...
# 3615  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3616  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3617  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3618  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3619  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                              title                            genres  \
# 0           The Attachment Diaries  Drama, Mystery, Thriller, Horror
# 1           The Attachment Diaries  Drama, Mystery, Thriller, Horror
# 2           The Attachment Diaries  Drama, Mystery, Thriller, Horror
# 3           The Attachment Diaries  Drama, Mystery, Thriller, Horror
# 4           The Attachment Diaries  Drama, Mystery, Thriller, Horror
# ...                            ...                               ...
# 3615  Love in the Time of Fentanyl                       Documentary
# 3616  Love in the Time of Fentanyl                       Documentary
# 3617  Love in the Time of Fentanyl                       Documentary
# 3618  Love in the Time of Fentanyl                       Documentary
# 3619  Love in the Time of Fentanyl                       Documentary
#
#      languages                         countries
# 0      Spanish                         Argentina
# 1      Spanish                         Argentina
# 2      Spanish                         Argentina
# 3      Spanish                         Argentina
# 4      Spanish                         Argentina
# ...        ...                               ...
# 3615   English  Canada, United States of America
# 3616   English  Canada, United States of America
# 3617   English  Canada, United States of America
# 3618   English  Canada, United States of America
# 3619   English  Canada, United States of America
#
# [3620 rows x 20 columns]

# %%
# Drop "byline.person" column
merged_df = merged_df.drop('byline.person', axis=1)

merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Drop "byline.person" column
# ----> 2 merged_df = merged_df.drop('byline.person', axis=1)
#       4 merged_df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['byline.person'] not found in axis"

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.apply(lambda x: x.map(lambda y: y if not isinstance(y, list) else str(y)))

merged_df.head(5)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#   byline.organization                                          title  \
# 0                None                         The Attachment Diaries
# 1                None  What’s Love Got to Do With It?’ Probably a Lo
# 2                None                           You Can Live Forever
# 3                None                      A Tourist’s Guide to Love
# 4                None                        Other People’s Children
#
#                              genres            languages  \
# 0  Drama, Mystery, Thriller, Horror              Spanish
# 1                               nan                  nan
# 2                    Drama, Romance      English, French
# 3                   Romance, Comedy  English, Vietnamese
# 4                     Drama, Comedy      French, English
#
#                           countries
# 0                         Argentina
# 1                               nan
# 2  Canada, United States of America
# 3          United States of America
# 4                            France

# %%
# Export data to CSV without the index
merged_df.to_csv('cleaned_data.csv', index=False)
